# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.
# Suggested reading:
# https://www.leiphone.com/news/201706/PamWKpfRFEI42McI.html

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span) # the length is fixed
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'anarchism', 'a', 'of', 'as', 'term', 'originated']

# %% [markdown]
# Train a skip-gram model. Suggested reading: https://www.leiphone.com/news/201706/eV8j3Nu8SMqGBnQB.html

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %% [markdown]
# Implementation. Suggested reading: https://www.leiphone.com/news/201706/QprrvzsrZCl4S2lw.html

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.205564
# Nearest to has: slain, mankind, phenomenological, rhombicuboctahedron, tansley, bocce, hydroxides, schiff,
# Nearest to be: inverted, radios, raja, course, moses, sox, hippolytus, mattia,
# Nearest to only: dago, viii, toppled, firefighters, adjacent, t, donnie, adenylate,
# Nearest to states: progression, rana, popcorn, plotters, mb, chiao, geiger, ranged,
# Nearest to are: benzoate, norse, croatia, azimuth, alhazred, baseline, faces, arrests,
# Nearest to new: damn, mortars, faces, screenplay, jin, wheaton, backpacker, hideo,
# Nearest to they: juggling, undertaking, arrange, riddle, olson, waldorf, archie, evaporative,
# Nearest to by: distillers, strategy, vivekananda, lineal, lilla, cracking, warmth, techno,
# Nearest to was: innovator, chaff, jag, sores, hostilities, ushered, falcon, wir,
# Nearest to over: affidavit, nominating, metropolis, mjh, cob, disembodied, fairgrounds, undulating,
# Nearest to than: bancroft, imitators, institut, defaults, specimen, copeland, newfound, sidewinder,
# Nearest to were: numbering, terraced, les, constrained, mainly, julmust, kilometers, peta,
# Nearest to four: thrash, hounds, gottes, reggaeton, microcontroller, zarathustra, delle, baccalaureate,
# Nearest to during: pbs, remittances, indefatigable, caliber, avc, cruisers, fanatic, ayyavazhi,
# Nearest to d: recording, doubleday, snafu, laos, swell, prevailing, independence, proliferation,
# Nearest to from: diacritical, sarcasm, paramilitaries, alluding, rappers, peoria, warr, dvb,
# Average loss at step 2000: 4.367829
# Average loss at step 4000: 3.860800
# Average loss at step 6000: 3.785357
# Average loss at step 8000: 3.684705
# Average loss at step 10000: 3.618282
# Nearest to has: had, is, have, was, nic, kristeva, debating, lamarr,
# Nearest to be: have, was, is, raja, limburgish, not, become, been,
# Nearest to only: ago, t, pinky, toppled, donnie, dago, kmt, firefighters,
# Nearest to states: progression, events, plotters, durch, motionless, inductees, like, ves,
# Nearest to are: were, is, have, baseline, was, grounded, azimuth, rg,
# Nearest to new: damn, julio, berkman, karim, sasson, faces, screenplay, albury,
# Nearest to they: we, he, there, not, it, evaporative, humus, cryonics,
# Nearest to by: was, as, kitt, in, handball, after, transport, progressed,
# Nearest to was: is, were, by, had, has, be, are, distributes,
# Nearest to over: cob, metropolis, commemorated, fairgrounds, affidavit, zeppelin, all, intransitive,
# Nearest to than: bancroft, deadline, or, ottomans, defaults, discontent, microfilm, eicher,
# Nearest to were: are, was, have, niro, racer, foobar, had, taught,
# Nearest to four: eight, six, five, three, seven, two, zero, nine,
# Nearest to during: united, intelligentsia, scherzo, ayyavazhi, of, transept, occupying, soviet,
# Nearest to d: b, bijections, swell, dramatized, and, psychiatrist, hindu, aedh,
# Nearest to from: in, rappers, diacritical, between, sic, warr, sarcasm, peoria,
# Average loss at step 12000: 3.606915
# Average loss at step 14000: 3.571149
# Average loss at step 16000: 3.406511
# Average loss at step 18000: 3.454242
# Average loss at step 20000: 3.539461
# Nearest to has: had, was, have, is, having, sheets, gridiron, mediaeval,
# Nearest to be: have, been, become, is, was, by, limburgish, refer,
# Nearest to only: toppled, ago, gyeonggi, fiftieth, possibly, synthetically, pinky, firefighters,
# Nearest to states: events, ves, progression, durch, plotters, motionless, shutout, abacus,
# Nearest to are: were, have, is, was, grounded, while, fannish, dwarfed,
# Nearest to new: damn, julio, karim, albury, csu, screenplay, prostate, berkman,
# Nearest to they: we, there, he, it, who, these, humus, not,
# Nearest to by: for, be, through, against, kitt, into, after, feodor,
# Nearest to was: is, were, has, had, be, became, are, intrigue,
# Nearest to over: cob, commemorated, intransitive, partial, fairgrounds, metropolis, zeppelin, aiming,
# Nearest to than: or, deadline, gigue, cheats, defaults, circassians, wellcome, ottomans,
# Nearest to were: are, was, have, had, niro, is, be, while,
# Nearest to four: three, six, eight, five, seven, two, nine, zero,
# Nearest to during: intelligentsia, united, soviet, after, scherzo, occupying, transept, ayyavazhi,
# Nearest to d: b, bijections, italian, ungodly, psychiatrist, grapefruit, french, ibid,
# Nearest to from: into, between, in, sic, rappers, after, paramilitaries, through,
# Average loss at step 22000: 3.505184
# Average loss at step 24000: 3.492022
# Average loss at step 26000: 3.478164
# Average loss at step 28000: 3.482266
# Average loss at step 30000: 3.502514
# Nearest to has: had, is, have, was, since, tortured, having, nic,
# Nearest to be: have, been, is, refer, was, limburgish, become, were,
# Nearest to only: ago, toppled, annually, fiftieth, possibly, underweight, gyeonggi, inheriting,
# Nearest to states: events, under, progression, ves, shutout, plotters, abacus, kingdom,
# Nearest to are: were, have, is, other, although, grounded, fannish, but,
# Nearest to new: julio, prostate, berkman, karim, damn, albury, csu, gpmg,
# Nearest to they: we, there, he, these, it, not, you, who,
# Nearest to by: in, were, morocco, was, for, with, as, after,
# Nearest to was: is, were, had, has, became, been, be, when,
# Nearest to over: commemorated, cob, partial, intransitive, bells, guards, aiming, voortrekkers,
# Nearest to than: gigue, cheats, circassians, deadline, but, defaults, sexagesimal, much,
# Nearest to were: are, was, have, had, by, been, is, being,
# Nearest to four: six, five, three, seven, eight, two, nine, zero,
# Nearest to during: after, in, before, contributor, when, intelligentsia, occupying, throughout,
# Nearest to d: b, italian, bijections, grapefruit, ungodly, underdog, psychiatrist, escher,
# Nearest to from: into, in, of, contributor, rappers, through, sic, after,
# Average loss at step 32000: 3.501552
# Average loss at step 34000: 3.493528
# Average loss at step 36000: 3.457980
# Average loss at step 38000: 3.298698
# Average loss at step 40000: 3.431704
# Nearest to has: had, have, was, is, having, cryo, tortured, superficially,
# Nearest to be: have, been, is, are, was, refer, become, beatrix,
# Nearest to only: fiftieth, synthetically, it, toppled, wyoming, chavez, ago, even,
# Nearest to states: kingdom, events, nations, progression, qasim, motionless, visa, happily,
# Nearest to are: were, have, is, be, while, but, pac, insolvency,
# Nearest to new: prostate, gpmg, damn, albury, julio, berkman, indo, karim,
# Nearest to they: we, there, he, it, you, these, i, humus,
# Nearest to by: as, with, be, morocco, starring, was, linemen, snowman,
# Nearest to was: is, were, has, had, became, be, been, when,
# Nearest to over: commemorated, bells, intransitive, wladislaus, partial, halal, between, about,
# Nearest to than: or, circassians, gigue, cheats, much, zane, considerably, innumerable,
# Nearest to were: are, have, was, had, those, although, be, these,
# Nearest to four: six, five, seven, three, eight, two, nine, zero,
# Nearest to during: after, in, at, before, from, when, occupying, until,
# Nearest to d: b, UNK, grapefruit, bijections, underdog, impervious, aedh, psychiatrist,
# Nearest to from: into, through, during, mashing, in, ultimate, of, contributor,
# Average loss at step 42000: 3.434559
# Average loss at step 44000: 3.457438
# Average loss at step 46000: 3.448773
# Average loss at step 48000: 3.350044
# Average loss at step 50000: 3.381893
# Nearest to has: had, have, was, is, having, superficially, jewels, since,
# Nearest to be: have, was, been, become, is, were, refer, attempt,
# Nearest to only: fiftieth, until, chavez, gyeonggi, always, first, within, lowest,
# Nearest to states: kingdom, events, nations, progression, maclisp, qasim, shop, vader,
# Nearest to are: were, is, have, these, those, tyndale, insolvency, was,
# Nearest to new: prostate, gpmg, lensing, literary, albury, berkman, chanter, guardian,
# Nearest to they: we, he, there, you, it, she, these, i,
# Nearest to by: morocco, through, was, miscellaneous, newly, improvisations, gnu, peacemaker,
# Nearest to was: is, has, became, were, had, be, being, been,
# Nearest to over: intransitive, bells, azores, guards, partial, ferris, dissolution, commemorated,
# Nearest to than: or, cheats, but, much, speeds, considerably, gigue, sexagesimal,
# Nearest to were: are, was, have, had, be, those, being, although,
# Nearest to four: five, six, seven, three, eight, nine, two, zero,
# Nearest to during: after, in, at, before, when, since, under, until,
# Nearest to d: b, grapefruit, m, underdog, r, bad, e, impervious,
# Nearest to from: into, through, after, contributor, alluding, in, rappers, hutchison,
# Average loss at step 52000: 3.437631
# Average loss at step 54000: 3.427530
# Average loss at step 56000: 3.438582
# Average loss at step 58000: 3.397870
# Average loss at step 60000: 3.395213
# Nearest to has: had, have, is, was, having, superficially, includes, eichmann,
# Nearest to be: been, have, was, is, refer, raja, were, become,
# Nearest to only: until, first, always, actually, chavez, follow, fiftieth, jonathan,
# Nearest to states: nations, kingdom, events, state, vader, sparc, happily, maclisp,
# Nearest to are: were, have, is, including, blackbody, although, these, usually,
# Nearest to new: prostate, berkman, damn, dwarves, sinauer, julio, literary, mauryan,
# Nearest to they: we, there, he, you, these, it, she, humus,
# Nearest to by: through, sforza, including, gnu, neisse, previously, catania, shi,
# Nearest to was: is, had, became, were, has, be, been, intrigue,
# Nearest to over: through, bells, azores, between, into, within, commemorated, wladislaus,
# Nearest to than: or, but, cheats, much, sexagesimal, speeds, gigue, circassians,
# Nearest to were: are, was, have, had, been, although, those, be,
# Nearest to four: five, six, eight, three, seven, nine, two, zero,
# Nearest to during: after, before, in, under, at, when, throughout, following,
# Nearest to d: b, m, underdog, grapefruit, h, e, r, c,
# Nearest to from: through, into, in, pwnage, rappers, southwards, ultimate, after,
# Average loss at step 62000: 3.244715
# Average loss at step 64000: 3.253804
# Average loss at step 66000: 3.404364
# Average loss at step 68000: 3.393827
# Average loss at step 70000: 3.365831
# Nearest to has: had, have, is, was, since, having, edvac, includes,
# Nearest to be: been, become, have, were, is, easily, being, by,
# Nearest to only: always, chavez, impressionism, positions, fiftieth, annually, follow, entirely,
# Nearest to states: kingdom, nations, events, state, governments, dormitory, ves, happily,
# Nearest to are: were, have, is, although, include, including, while, heaviest,
# Nearest to new: prostate, csu, damn, literary, julio, expressionism, sinauer, animators,
# Nearest to they: we, there, he, you, it, she, humus, these,
# Nearest to by: through, newly, be, sae, techno, mmorpg, during, eisenman,
# Nearest to was: is, had, has, were, became, been, when, although,
# Nearest to over: azores, through, bells, wladislaus, about, commemorated, intransitive, fabled,
# Nearest to than: or, and, but, wellcome, cheats, much, circumvent, circassians,
# Nearest to were: are, was, have, be, had, been, while, although,
# Nearest to four: six, five, seven, eight, three, zero, nine, two,
# Nearest to during: after, before, until, in, at, under, throughout, through,
# Nearest to d: b, h, r, impervious, underdog, grapefruit, aedh, f,
# Nearest to from: through, into, across, southwards, motivates, rappers, unavoidable, between,
# Average loss at step 72000: 3.378731
# Average loss at step 74000: 3.350663
# Average loss at step 76000: 3.318383
# Average loss at step 78000: 3.352345
# Average loss at step 80000: 3.380876
# Nearest to has: had, have, is, was, having, since, edvac, although,
# Nearest to be: been, being, have, become, easily, is, limburgish, refer,
# Nearest to only: next, always, synthetically, fiftieth, actually, first, until, enigmatic,
# Nearest to states: kingdom, nations, state, events, ves, vader, us, sparc,
# Nearest to are: were, have, is, those, although, these, including, include,
# Nearest to new: resulting, berkman, csu, lensing, albury, sinauer, aia, chanter,
# Nearest to they: we, there, he, you, it, these, she, honeybee,
# Nearest to by: through, starring, using, newly, including, sae, after, during,
# Nearest to was: is, were, became, had, has, began, being, robber,
# Nearest to over: between, wladislaus, bells, about, through, around, kb, within,
# Nearest to than: but, much, wellcome, while, circassians, or, speeds, circumvent,
# Nearest to were: are, was, had, have, although, including, while, being,
# Nearest to four: five, six, three, seven, eight, two, nine, zero,
# Nearest to during: after, in, before, until, despite, when, through, throughout,
# Nearest to d: b, f, h, impervious, e, grapefruit, p, perished,
# Nearest to from: through, into, rappers, danelaw, across, after, via, in,
# Average loss at step 82000: 3.406505
# Average loss at step 84000: 3.413041
# Average loss at step 86000: 3.389007
# Average loss at step 88000: 3.354124
# Average loss at step 90000: 3.368074
# Nearest to has: had, have, is, was, having, since, edvac, includes,
# Nearest to be: been, become, have, being, easily, is, was, refer,
# Nearest to only: even, fiftieth, enigmatic, either, exactly, ferret, actually, entirely,
# Nearest to states: kingdom, nations, state, vader, pluralism, events, us, geology,
# Nearest to are: were, is, have, these, include, although, blackbody, wickedness,
# Nearest to new: prostate, berkman, modern, animators, sinauer, damn, lensing, different,
# Nearest to they: we, he, there, you, she, it, humus, these,
# Nearest to by: through, sae, during, newly, techno, using, with, when,
# Nearest to was: is, had, became, were, has, been, be, distributes,
# Nearest to over: within, between, wladislaus, around, bells, through, about, across,
# Nearest to than: or, wellcome, much, speeds, affirming, cheats, envisioned, thessalonians,
# Nearest to were: are, was, had, have, while, although, these, those,
# Nearest to four: five, seven, six, eight, three, nine, two, zero,
# Nearest to during: after, in, until, before, through, under, while, when,
# Nearest to d: b, grapefruit, perished, f, h, killers, pathophysiology, underdog,
# Nearest to from: through, into, across, during, rappers, under, southwards, danelaw,
# Average loss at step 92000: 3.398063
# Average loss at step 94000: 3.254540
# Average loss at step 96000: 3.360407
# Average loss at step 98000: 3.241931
# Average loss at step 100000: 3.356627
# Nearest to has: had, have, is, was, having, since, edvac, includes,
# Nearest to be: been, have, become, easily, being, is, was, refer,
# Nearest to only: exactly, fiftieth, even, always, either, enigmatic, lowest, not,
# Nearest to states: nations, kingdom, state, events, geology, vader, us, pluralism,
# Nearest to are: were, have, while, although, those, is, be, these,
# Nearest to new: modern, documenting, dwarves, different, prostate, expressionism, berkman, molotov,
# Nearest to they: we, he, there, you, it, she, i, humans,
# Nearest to by: through, sae, including, using, sforza, when, during, gnu,
# Nearest to was: is, became, been, were, had, has, being, be,
# Nearest to over: wladislaus, across, through, around, within, about, between, cow,
# Nearest to than: or, cheats, wellcome, much, herg, speeds, efficiently, while,
# Nearest to were: are, have, was, these, had, those, being, including,
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Nearest to during: after, in, following, despite, until, throughout, at, through,
# Nearest to d: b, c, impervious, bijections, h, bothnian, perished, aeroplanes,
# Nearest to from: into, through, across, in, rappers, alluding, during, of,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0
 
def generate_batch(batch_size, bag_window):
    global data_index
    span = 2 * bag_window + 1 # [ bag_window target bag_window ]
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        buffer_list = list(buffer)
        labels[i, 0] = buffer_list.pop(bag_window)
        batch[i] = buffer_list
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels
 
print('data:', [reverse_dictionary[di] for di in data[:16]])
 
for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
bag_window = 2  # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64  # Number of negative examples to sample.
 
graph = tf.Graph()
 
with graph.as_default(), tf.device('/cpu:0'):
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
 
    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
 
    # Model.
    # Look up embeddings for inputs.
    embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embeds, 1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
 
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001
 
with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
            batch_size, bag_window)
        feed_dict = {train_dataset: batch_data, train_labels: batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.495039
# Nearest to this: magee, mentions, belleville, ananda, inen, inferences, maori, sterilized,
# Nearest to th: describing, negotiated, advertisement, jams, ryu, diagnostics, heston, attract,
# Nearest to used: drowns, mistreatment, donegal, swelled, frankenstein, colitis, uniforms, hamdi,
# Nearest to five: freeh, operative, palsy, feistel, empowered, restatement, transposed, zinc,
# Nearest to i: palatine, agriculture, frontispiece, kellerman, arb, imitators, widest, anzac,
# Nearest to to: practices, scarring, aggressors, shoot, mifune, pars, bill, illuminating,
# Nearest to on: assignments, inspectors, strassburg, fernandez, sura, wildfire, lecturer, liturgical,
# Nearest to known: brooker, earthbound, axillary, starship, tigris, calypso, metroid, cornish,
# Nearest to seven: implicit, flinders, zen, newline, executables, justly, suck, amedeo,
# Nearest to were: gentleman, mahommed, sancti, viennese, turntable, sooty, satellite, ais,
# Nearest to would: doorways, frequently, diagnosed, propaganda, summa, parque, execution, wattle,
# Nearest to other: scans, somerville, commando, cuboctahedron, cradle, esv, dreaded, thirst,
# Nearest to united: cline, ro, megawatts, chile, tremors, dignified, mays, coward,
# Nearest to system: consulted, additionally, flashpoint, ahmad, excitement, heaney, diffuse, varnish,
# Nearest to b: gluconeogenesis, d, jockey, roberts, stereochemistry, space, rational, storytelling,
# Nearest to first: zama, myrtle, asphyxiation, withdrew, necronomicon, primus, artistically, mouton,
# Average loss at step 2000: 4.525006
# Average loss at step 4000: 3.938909
# Average loss at step 6000: 3.694292
# Average loss at step 8000: 3.657198
# Average loss at step 10000: 3.624509
# Nearest to this: it, which, that, a, the, shevat, farrar, procreation,
# Nearest to th: levellers, ua, eight, thirdly, attract, paran, chirality, collett,
# Nearest to used: considered, known, called, referred, written, selamat, cataloguing, available,
# Nearest to five: seven, four, three, zero, nine, eight, two, six,
# Nearest to i: g, you, ii, buckingham, christo, subsidence, unwilling, perpetual,
# Nearest to to: would, may, vinci, synapse, canc, can, will, pais,
# Nearest to on: in, upon, moabites, from, gabbro, patrons, mimicked, nicene,
# Nearest to known: used, well, such, referred, far, measured, axillary, angkor,
# Nearest to seven: eight, five, six, four, zero, nine, three, timesharing,
# Nearest to were: are, was, had, namur, auteur, astronauts, howe, arunachal,
# Nearest to would: may, can, will, could, should, might, did, must,
# Nearest to other: these, various, scientific, legge, many, conveying, demyelinating, sportswriter,
# Nearest to united: bandai, brazilians, chile, mesopotamian, japan, atreides, skier, rico,
# Nearest to system: ahmad, filaments, heaney, tryptophan, rel, offline, senegal, ballard,
# Nearest to b: polarization, laurentiis, microsystems, paleontology, matrix, pocket, debunked, hook,
# Nearest to first: last, second, same, portal, bylaws, denying, third, mik,
# Average loss at step 12000: 3.562839
# Average loss at step 14000: 3.316088
# Average loss at step 16000: 3.414416
# Average loss at step 18000: 3.401809
# Average loss at step 20000: 3.378944
# Nearest to this: it, another, which, zee, what, the, common, netscape,
# Nearest to th: nineteenth, paran, ua, collett, temples, opportunity, twentieth, nd,
# Nearest to used: referred, known, considered, written, found, available, given, seen,
# Nearest to five: six, four, seven, eight, three, zero, two, nine,
# Nearest to i: g, ii, elca, abandon, you, browsing, mail, accusation,
# Nearest to to: would, will, can, may, might, could, should, bbses,
# Nearest to on: upon, through, in, into, mystique, gabbro, subordinated, misheard,
# Nearest to known: used, referred, described, seen, such, well, measured, regarded,
# Nearest to seven: eight, five, four, six, zero, three, nine, one,
# Nearest to were: are, was, is, had, became, been, being, smoother,
# Nearest to would: will, may, could, can, should, might, must, did,
# Nearest to other: various, these, others, voltages, different, some, bit, many,
# Nearest to united: japan, cav, bandai, walruses, atreides, bullion, devonshire, codasyl,
# Nearest to system: systems, ana, program, scanned, magyar, eckhart, company, crosley,
# Nearest to b: disaccharide, c, d, eclipsing, borrower, matrix, storytelling, slavonic,
# Nearest to first: third, same, second, last, next, following, orally, during,
# Average loss at step 22000: 3.357745
# Average loss at step 24000: 3.377691
# Average loss at step 26000: 3.275865
# Average loss at step 28000: 3.242845
# Average loss at step 30000: 3.249980
# Nearest to this: it, which, zee, another, what, that, aleksandr, slr,
# Nearest to th: nineteenth, twentieth, nd, st, rd, ua, paran, copernican,
# Nearest to used: known, seen, referred, available, considered, found, written, able,
# Nearest to five: four, eight, three, seven, zero, two, six, nine,
# Nearest to i: g, ii, you, we, unalaska, mail, shoshone, corrections,
# Nearest to to: will, can, would, should, may, could, must, vinci,
# Nearest to on: upon, through, about, embryo, patrons, within, before, over,
# Nearest to known: used, referred, seen, described, such, regarded, opposed, defined,
# Nearest to seven: three, nine, eight, five, six, four, zero, two,
# Nearest to were: are, was, is, being, include, banu, had, have,
# Nearest to would: will, could, may, can, should, might, must, cannot,
# Nearest to other: various, different, rather, smaller, both, larger, many, others,
# Nearest to united: cav, impressive, egyptian, walruses, japan, sahih, nation, akron,
# Nearest to system: systems, schooling, ana, durrell, nausica, budweiser, process, mamluks,
# Nearest to b: d, mammal, disaccharide, c, planetarium, microsystems, markers, underside,
# Nearest to first: second, last, same, next, final, third, original, malden,
# Average loss at step 32000: 3.190182
# Average loss at step 34000: 3.178312
# Average loss at step 36000: 3.206106
# Average loss at step 38000: 3.046063
# Average loss at step 40000: 3.146861
# Nearest to this: which, it, what, the, that, another, grammatik, resurrect,
# Nearest to th: twentieth, nd, nineteenth, rd, st, nine, ua, tenth,
# Nearest to used: seen, known, available, written, referred, considered, described, taken,
# Nearest to five: six, seven, four, eight, three, zero, two, nine,
# Nearest to i: g, ii, ta, you, saratoga, elca, me, cougars,
# Nearest to to: could, must, will, might, misinformation, towards, clem, would,
# Nearest to on: upon, under, at, through, about, in, synoptic, bauer,
# Nearest to known: referred, used, seen, described, regarded, such, opposed, considered,
# Nearest to seven: six, five, eight, four, three, zero, nine, one,
# Nearest to were: are, was, is, being, fridays, have, had, punctuation,
# Nearest to would: will, could, can, should, might, may, must, did,
# Nearest to other: various, different, these, certain, others, more, both, those,
# Nearest to united: cav, instantaneously, brazilians, walruses, akron, plowman, organizational, japan,
# Nearest to system: systems, process, function, walpole, situation, person, area, position,
# Nearest to b: d, c, agriculturally, etruscans, p, actress, bahia, morisot,
# Nearest to first: last, second, next, same, most, third, clarifies, original,
# Average loss at step 42000: 3.125135
# Average loss at step 44000: 3.076921
# Average loss at step 46000: 3.043693
# Average loss at step 48000: 2.997684
# Average loss at step 50000: 3.074587
# Nearest to this: which, it, that, zee, lenny, postcard, bakr, resurrect,
# Nearest to th: nineteenth, nd, twentieth, st, nine, rd, tenth, eighteenth,
# Nearest to used: available, seen, found, referred, written, employed, described, required,
# Nearest to five: seven, four, six, three, eight, nine, zero, two,
# Nearest to i: g, ii, you, bedouins, dewan, we, usurper, livres,
# Nearest to to: must, will, would, should, cruzi, vinci, might, towards,
# Nearest to on: upon, under, in, into, within, marketing, through, across,
# Nearest to known: described, referred, seen, regarded, used, considered, defined, opposed,
# Nearest to seven: five, four, six, three, eight, nine, zero, two,
# Nearest to were: are, was, is, had, being, include, be, activex,
# Nearest to would: will, might, could, should, must, can, may, cannot,
# Nearest to other: various, others, both, these, different, allegories, larger, smaller,
# Nearest to united: cav, us, impressive, disapproval, akron, organizational, runways, japan,
# Nearest to system: systems, program, mircea, area, dying, offline, cosmos, heraldic,
# Nearest to b: d, farthing, mathematician, lear, continuum, muscovite, chubut, nucleation,
# Nearest to first: second, last, next, same, third, jacobi, weathering, earliest,
# Average loss at step 52000: 3.082432
# Average loss at step 54000: 2.907278
# Average loss at step 56000: 3.065701
# Average loss at step 58000: 3.080770
# Average loss at step 60000: 3.039837
# Nearest to this: which, it, that, another, what, largely, whatever, upstart,
# Nearest to th: st, nine, nd, nineteenth, twentieth, tenth, rd, levellers,
# Nearest to used: known, referred, seen, applied, designed, employed, shown, intended,
# Nearest to five: three, seven, six, four, eight, zero, nine, two,
# Nearest to i: ii, g, you, she, they, ross, felsic, barrister,
# Nearest to to: would, will, can, could, must, might, cannot, should,
# Nearest to on: upon, in, around, within, through, bauer, antitank, under,
# Nearest to known: referred, used, regarded, described, seen, opposed, served, possible,
# Nearest to seven: six, eight, four, five, nine, three, zero, vic,
# Nearest to were: are, was, is, had, various, have, include, newly,
# Nearest to would: will, could, should, might, must, may, can, cannot,
# Nearest to other: various, larger, certain, others, rather, individual, smaller, turbulence,
# Nearest to united: setter, instantaneously, existing, impressive, plowman, akron, cav, tachi,
# Nearest to system: systems, program, mcenroe, kumamoto, method, motivations, spectroscopy, area,
# Nearest to b: d, k, qquad, etruscans, capra, c, wendell, turpin,
# Nearest to first: last, next, same, second, jacobi, original, latter, oldest,
# Average loss at step 62000: 2.917836
# Average loss at step 64000: 3.007361
# Average loss at step 66000: 2.976595
# Average loss at step 68000: 2.999352
# Average loss at step 70000: 2.944773
# Nearest to this: which, that, what, it, another, the, zee, whatever,
# Nearest to th: nineteenth, twentieth, st, nd, tenth, nine, eighteenth, fifth,
# Nearest to used: known, referred, introduced, employed, designed, available, required, found,
# Nearest to five: four, six, seven, eight, three, zero, nine, two,
# Nearest to i: you, ii, we, g, takashi, they, spiny, ross,
# Nearest to to: would, towards, must, might, could, can, will, clem,
# Nearest to on: upon, in, through, within, gust, behind, along, under,
# Nearest to known: used, referred, regarded, described, seen, served, opposed, possible,
# Nearest to seven: eight, six, five, nine, four, three, zero, spiracles,
# Nearest to were: are, was, is, include, have, had, banu, naturalis,
# Nearest to would: might, will, could, can, may, should, must, cannot,
# Nearest to other: various, rather, others, both, different, rigging, certain, these,
# Nearest to united: setter, instantaneously, japan, uk, us, cav, impressive, americanized,
# Nearest to system: systems, process, method, motivations, program, position, unit, practice,
# Nearest to b: qquad, d, f, anagrams, letter, etruscans, p, c,
# Nearest to first: last, second, next, earliest, best, third, final, latter,
# Average loss at step 72000: 2.925872
# Average loss at step 74000: 2.959601
# Average loss at step 76000: 2.927594
# Average loss at step 78000: 2.527472
# Average loss at step 80000: 2.620460
# Nearest to this: another, which, any, it, what, grammatik, every, consults,
# Nearest to th: nd, twentieth, nineteenth, st, fifth, tenth, rd, eighteenth,
# Nearest to used: applied, seen, intended, referred, employed, required, designed, known,
# Nearest to five: seven, eight, six, four, three, nine, two, zero,
# Nearest to i: ii, you, we, iii, g, they, whitehead, neon,
# Nearest to to: would, towards, must, might, will, could, should, cannot,
# Nearest to on: upon, through, in, toward, near, antitank, concerning, inside,
# Nearest to known: referred, described, regarded, seen, used, opposed, served, available,
# Nearest to seven: six, eight, five, four, three, nine, zero, two,
# Nearest to were: are, was, is, include, many, had, exist, banu,
# Nearest to would: will, might, could, should, must, may, can, does,
# Nearest to other: different, various, earlier, rather, these, others, both, many,
# Nearest to united: us, setter, tachi, lemming, xxvii, denmark, cav, akron,
# Nearest to system: systems, method, program, motivations, model, process, framework, principle,
# Nearest to b: d, bodywork, sudbury, targaryen, longman, kelvins, consisting, recipient,
# Nearest to first: last, next, second, third, best, earliest, oldest, final,
# Average loss at step 82000: 2.867255
# Average loss at step 84000: 2.858885
# Average loss at step 86000: 2.947723
# Average loss at step 88000: 2.934406
# Average loss at step 90000: 2.744796
# Nearest to this: which, another, it, what, the, buddhism, whatever, xxxv,
# Nearest to th: twentieth, nd, st, fifth, nineteenth, tenth, nine, third,
# Nearest to used: seen, required, employed, intended, referred, cited, designed, described,
# Nearest to five: six, four, three, seven, eight, zero, two, nine,
# Nearest to i: ii, we, you, g, middleweight, bedouins, they, gourmet,
# Nearest to to: cannot, must, might, should, can, would, vinci, synapse,
# Nearest to on: upon, through, about, in, bauer, within, onto, under,
# Nearest to known: referred, described, regarded, used, seen, opposed, available, understood,
# Nearest to seven: eight, six, four, five, three, nine, zero, two,
# Nearest to were: are, was, have, include, vantage, is, various, selector,
# Nearest to would: will, could, should, might, must, can, cannot, may,
# Nearest to other: various, different, rigging, both, phobos, others, rather, all,
# Nearest to united: us, tachi, setter, lemming, baltic, cav, confederate, akron,
# Nearest to system: systems, program, method, offline, process, gust, callers, manchu,
# Nearest to b: d, msg, p, salmonella, brokered, ramirez, erowid, anagrams,
# Nearest to first: last, second, next, earliest, third, best, final, oldest,
# Average loss at step 92000: 2.903982
# Average loss at step 94000: 2.922009
# Average loss at step 96000: 2.935613
# Average loss at step 98000: 2.697390
# Average loss at step 100000: 2.752809
# Nearest to this: another, it, what, which, whatever, zee, any, the,
# Nearest to th: twentieth, nd, nineteenth, st, fifth, eighteenth, tenth, third,
# Nearest to used: introduced, referred, found, required, intended, designed, employed, published,
# Nearest to five: four, seven, eight, six, three, nine, two, zero,
# Nearest to i: ii, g, we, you, iii, they, spiny, unalaska,
# Nearest to to: might, cannot, must, can, towards, would, should, may,
# Nearest to on: upon, through, within, about, under, in, toward, retrieved,
# Nearest to known: described, referred, regarded, used, remembered, defined, opposed, seen,
# Nearest to seven: eight, four, five, six, three, nine, zero, two,
# Nearest to were: are, was, is, banu, have, newly, had, naturalis,
# Nearest to would: will, could, should, might, must, can, did, may,
# Nearest to other: various, different, others, these, phobos, multiple, certain, rigging,
# Nearest to united: setter, confederate, baltic, cav, japan, xxvii, tachi, lemming,
# Nearest to system: systems, program, method, region, magistrates, process, tm, framework,
# Nearest to b: d, msg, mathematician, qquad, adopts, lagrand, childbirth, kroeber,
# Nearest to first: last, second, next, third, final, original, earliest, fourth,

# %%
num_points = 400
 
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points + 1, :])

def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15, 15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i, :]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()
 
 
words = [reverse_dictionary[i] for i in range(1, num_points + 1)]
plot(two_d_embeddings, words)
